# %% [markdown]
# <a href="https://colab.research.google.com/github/Lorde-jacare/truth-table/blob/main/gerador_de_tabelas_verdade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
#Determinar as operações lógicas
def disjuncao_exclusiva(x, y):
    return not((not (x) or y) and (not(y) or x))
def condicional(x, y):
    return not(x) or y
def bicondicional(x, y):
    return (not(x) or y) and (not(y) or x)
#Descobrir quais serão as operações
sair = 0
equação = []
con = ()
dis = ()
edis = ()
cond = ()
bicond = ()
variavel = input("Monte a equação (variável): ")
print(f"\n{variavel}\n")
equação.append(variavel)
print("conjunção(∧) - 1\ndisjunção(V) - 2\ndisjução exclusiva - 3")
print("condicional(→) - 4\nbicondicional(↔) - 5\n")
operador = int(input("Qual a operação? "))
if operador == 1:
    con = "∧"
    print(f"\n{variavel} {con}")
    variavel2 = str(input("\nMonte a equação (variável)"))
    print(f"\n{variavel} {con} {variavel2}")
    equação.append(con)
    equação.append(variavel2)
elif operador == 2:
    dis = "V"
    print(f"\n{variavel} {dis}")
    variavel2 = str(input("Monte a equação (variável)"))
    print(f"\n{variavel} {dis} {variavel2}")
    equação.append(dis)
    equação.append(variavel2)
elif operador == 3:
    edis = "V̲"
    print(f"\n{variavel} {edis}")
    variavel2 = str(input("Monte a equação (variável)"))
    print(f"\n{variavel} {edis} {variavel2}")
    equação.append(edis)
    equação.append(variavel2)
elif operador == 4:
    cond = "→"
    print(f"\n{variavel} {cond}")
    variavel2 = str(input("Monte a equação (variável)"))
    print(f"\n{variavel} {cond} {variavel2}")
    equação.append(cond)
    equação.append(variavel2)
elif operador == 5:
    bicond = "↔"
    print(f"\n{variavel} {bicond}")
    variavel2 = str(input("Monte a equação (variável)"))
    print(f"\n{variavel} {bicond} {variavel2}")
    equação.append(bicond)
    equação.append(variavel2)
#Realizar todas as operações lógicas

##Tabelas das proposições atômicas

valor_variaveis = np.array([[True, True],[True, False],[False, True],[False, False]])
if equação[0] =="~p" and equação[2] == 'q':
    neg1 = np.array([[False], [False], [True], [True]])
    valor_variaveis = np.hstack((valor_variaveis, neg1))
elif equação[0] =="p" and equação[2] =="~q":
    neg2 = np.array([[False], [True], [False], [True]])
    valor_variaveis = np.hstack((valor_variaveis, neg2))
elif equação[0] == "~p" and equação[2] =="~q":
    neg1 = np.array([[False], [False], [True], [True]])
    neg2 = np.array([[False], [True], [False], [True]])
    negs = np.hstack((neg1, neg2))
    valor_variaveis = np.hstack((valor_variaveis, negs))

##Conjunção

if equação[1] == con and equação[0] == "p" and equação[2] == "q":
    titulo = np.array([variavel, variavel2, variavel + con + variavel2])
    resultado = np.array([[valor_variaveis[0,0] and valor_variaveis[0,1]],
                          [valor_variaveis[1,0] and valor_variaveis[1,1]],
                          [valor_variaveis[2,0] and valor_variaveis[2,1]],
                          [valor_variaveis[3,0] and valor_variaveis[3,1]]])
elif equação[1] == con and equação[0] == "~p" and equação[2] == "q":
    titulo = np.array([variavel.replace('~', ''), variavel2, variavel, variavel + con + variavel2])
    resultado = np.array([[valor_variaveis[0,2] and valor_variaveis[0,1]],
                          [valor_variaveis[1,2] and valor_variaveis[1,1]],
                          [valor_variaveis[2,2] and valor_variaveis[2,1]],
                          [valor_variaveis[3,2] and valor_variaveis[3,1]]])
elif equação[1] == con and equação[0] == "p" and equação[2] == "~q":
    titulo = np.array([variavel, variavel2.replace('~', ''), variavel2, variavel + con + variavel2])
    resultado = np.array([[valor_variaveis[0,0] and valor_variaveis[0,2]],
                          [valor_variaveis[1,0] and valor_variaveis[1,2]],
                          [valor_variaveis[2,0] and valor_variaveis[2,2]],
                          [valor_variaveis[3,0] and valor_variaveis[3,2]]])
elif equação[1] == con and equação[0] == "~p" and equação[2] == "~q":
    titulo = np.array([variavel.replace('~', ''), variavel2.replace('~', ''), variavel, variavel2, variavel + con + variavel2])
    resultado = np.array([[valor_variaveis[0,2] and valor_variaveis[0,3]],
                          [valor_variaveis[1,2] and valor_variaveis[1,3]],
                          [valor_variaveis[2,2] and valor_variaveis[2,3]],
                          [valor_variaveis[3,2] and valor_variaveis[3,3]]])

##Disjunão

if equação[1] == dis and equação[0] == "p" and equação[2] == "q":
    titulo = np.array([variavel, variavel2, variavel + dis + variavel2])
    resultado = np.array([[valor_variaveis[0,0] or valor_variaveis[0,1]],
                          [valor_variaveis[1,0] or valor_variaveis[1,1]],
                          [valor_variaveis[2,0] or valor_variaveis[2,1]],
                          [valor_variaveis[3,0] or valor_variaveis[3,1]]])
elif equação[1] == dis and equação[0] == "~p" and equação[2] == "q":
    titulo = np.array([variavel.replace('~', ''), variavel2, variavel, variavel + dis + variavel2])
    resultado = np.array([[valor_variaveis[0,2] or valor_variaveis[0,1]],
                          [valor_variaveis[1,2] or valor_variaveis[1,1]],
                          [valor_variaveis[2,2] or valor_variaveis[2,1]],
                          [valor_variaveis[3,2] or valor_variaveis[3,1]]])
elif equação[1] == dis and equação[0] == "p" and equação[2] == "~q":
    titulo = np.array([variavel, variavel2.replace('~', ''), variavel2, variavel + dis + variavel2])
    resultado = np.array([[valor_variaveis[0,0] or valor_variaveis[0,2]],
                          [valor_variaveis[1,0] or valor_variaveis[1,2]],
                          [valor_variaveis[2,0] or valor_variaveis[2,2]],
                          [valor_variaveis[3,0] or valor_variaveis[3,2]]])
elif equação[1] == dis and equação[0] == "~p" and equação[2] == "~q":
    titulo = np.array([variavel.replace('~', ''), variavel2.replace('~', ''), variavel, variavel2, variavel + dis + variavel2])
    resultado = np.array([[valor_variaveis[0,2] or valor_variaveis[0,3]],
                          [valor_variaveis[1,2] or valor_variaveis[1,3]],
                          [valor_variaveis[2,2] or valor_variaveis[2,3]],
                          [valor_variaveis[3,2] or valor_variaveis[3,3]]])
    
#Disjunção exclusiva

if equação[1] == edis and equação[0] == "p" and equação[2] == "q":
    titulo = np.array([variavel, variavel2, variavel + edis + variavel2])
    resultado = np.array([[disjuncao_exclusiva(valor_variaveis[0,0],valor_variaveis[0,1])],
                          [disjuncao_exclusiva(valor_variaveis[1,0],valor_variaveis[1,1])],
                          [disjuncao_exclusiva(valor_variaveis[2,0],valor_variaveis[2,1])],
                          [disjuncao_exclusiva(valor_variaveis[3,0],valor_variaveis[3,1])]])
elif equação[1] == edis and equação[0] == "~p" and equação[2] == "q":
    titulo = np.array([variavel.replace('~', ''), variavel2, variavel, variavel + edis + variavel2])
    resultado = np.array([[disjuncao_exclusiva(valor_variaveis[0,2],valor_variaveis[0,1])],
                          [disjuncao_exclusiva(valor_variaveis[1,2],valor_variaveis[1,1])],
                          [disjuncao_exclusiva(valor_variaveis[2,2],valor_variaveis[2,1])],
                          [disjuncao_exclusiva(valor_variaveis[3,2],valor_variaveis[3,1])]])
elif equação[1] == edis and equação[0] == "p" and equação[2] == "~q":
    titulo = np.array([variavel, variavel2.replace('~', ''), variavel2, variavel + edis + variavel2])
    resultado = np.array([[disjuncao_exclusiva(valor_variaveis[0,0],valor_variaveis[0,2])],
                          [disjuncao_exclusiva(valor_variaveis[1,0],valor_variaveis[1,2])],
                          [disjuncao_exclusiva(valor_variaveis[2,0],valor_variaveis[2,2])],
                          [disjuncao_exclusiva(valor_variaveis[3,0],valor_variaveis[3,2])]])
elif equação[1] == edis and equação[0] == "~p" and equação[2] == "~q":
    titulo = np.array([variavel.replace('~', ''), variavel2.replace('~', ''), variavel, variavel2, variavel + edis + variavel2])
    resultado = np.array([[disjuncao_exclusiva(valor_variaveis[0,2],valor_variaveis[0,3])],
                          [disjuncao_exclusiva(valor_variaveis[1,2],valor_variaveis[1,3])],
                          [disjuncao_exclusiva(valor_variaveis[2,2],valor_variaveis[2,3])],
                          [disjuncao_exclusiva(valor_variaveis[3,2],valor_variaveis[3,3])]])

#Condicional 

if equação[1] == cond and equação[0] == "p" and equação[2] == "q":
    titulo = np.array([variavel, variavel2, variavel + cond + variavel2])
    resultado = np.array([[condicional(valor_variaveis[0,0],valor_variaveis[0,1])],
                          [condicional(valor_variaveis[1,0],valor_variaveis[1,1])],
                          [condicional(valor_variaveis[2,0],valor_variaveis[2,1])],
                          [condicional(valor_variaveis[3,0],valor_variaveis[3,1])]])
elif equação[1] == cond and equação[0] == "~p" and equação[2] == "q":
    titulo = np.array([variavel.replace('~', ''), variavel2, variavel, variavel + cond + variavel2])
    resultado = np.array([[condicional(valor_variaveis[0,2],valor_variaveis[0,1])],
                          [condicional(valor_variaveis[1,2],valor_variaveis[1,1])],
                          [condicional(valor_variaveis[2,2],valor_variaveis[2,1])],
                          [condicional(valor_variaveis[3,2],valor_variaveis[3,1])]])
elif equação[1] == cond and equação[0] == "p" and equação[2] == "~q":
    titulo = np.array([variavel, variavel2.replace('~', ''), variavel2, variavel + cond + variavel2])
    resultado = np.array([[condicional(valor_variaveis[0,0],valor_variaveis[0,2])],
                          [condicional(valor_variaveis[1,0],valor_variaveis[1,2])],
                          [condicional(valor_variaveis[2,0],valor_variaveis[2,2])],
                          [condicional(valor_variaveis[3,0],valor_variaveis[3,2])]])
elif equação[1] == cond and equação[0] == "~p" and equação[2] == "~q":
    titulo = np.array([variavel.replace('~', ''), variavel2.replace('~', ''), variavel, variavel2, variavel + cond + variavel2])
    resultado = np.array([[condicional(valor_variaveis[0,2],valor_variaveis[0,3])],
                          [condicional(valor_variaveis[1,2],valor_variaveis[1,3])],
                          [condicional(valor_variaveis[2,2],valor_variaveis[2,3])],
                          [condicional(valor_variaveis[3,2],valor_variaveis[3,3])]])
    
#Bicondicional

if equação[1] == bicond and equação[0] == "p" and equação[2] == "q":
    titulo = np.array([variavel, variavel2, variavel + bicond + variavel2])
    resultado = np.array([[bicondicional(valor_variaveis[0,0],valor_variaveis[0,1])],
                          [bicondicional(valor_variaveis[1,0],valor_variaveis[1,1])],
                          [bicondicional(valor_variaveis[2,0],valor_variaveis[2,1])],
                          [bicondicional(valor_variaveis[3,0],valor_variaveis[3,1])]])
elif equação[1] == bicond and equação[0] == "~p" and equação[2] == "q":
    titulo = np.array([variavel.replace('~', ''), variavel2, variavel, variavel + bicond + variavel2])
    resultado = np.array([[bicondicional(valor_variaveis[0,2],valor_variaveis[0,1])],
                          [bicondicional(valor_variaveis[1,2],valor_variaveis[1,1])],
                          [bicondicional(valor_variaveis[2,2],valor_variaveis[2,1])],
                          [bicondicional(valor_variaveis[3,2],valor_variaveis[3,1])]])
elif equação[1] == bicond and equação[0] == "p" and equação[2] == "~q":
    titulo = np.array([variavel, variavel2.replace('~', ''), variavel2, variavel + bicond + variavel2])
    resultado = np.array([[bicondicional(valor_variaveis[0,0],valor_variaveis[0,2])],
                          [bicondicional(valor_variaveis[1,0],valor_variaveis[1,2])],
                          [bicondicional(valor_variaveis[2,0],valor_variaveis[2,2])],
                          [bicondicional(valor_variaveis[3,0],valor_variaveis[3,2])]])
elif equação[1] == bicond and equação[0] == "~p" and equação[2] == "~q":
    titulo = np.array([variavel.replace('~', ''), variavel2.replace('~', ''), variavel, variavel2, variavel + bicond + variavel2])
    resultado = np.array([[bicondicional(valor_variaveis[0,2],valor_variaveis[0,3])],
                          [bicondicional(valor_variaveis[1,2],valor_variaveis[1,3])],

                          [bicondicional(valor_variaveis[2,2],valor_variaveis[2,3])],
                          [bicondicional(valor_variaveis[3,2],valor_variaveis[3,3])]])

#Entregar a tabela verdade 
booleans = np.hstack((valor_variaveis, resultado))
print("\nTabela Verdade\n")
print(np.vstack((titulo, booleans)))
# Out:
# Monte a equação (variável): p
#
# p
#
# conjunção(∧) - 1
# disjunção(V) - 2
# disjução exclusiva - 3
# condicional(→) - 4
# bicondicional(↔) - 5
#
# Qual a operação? 3
#
# p V̲
# Monte a equação (variável)~q
#
# p V̲ ~q
#
# Tabela Verdade
#
# [['p' 'q' '~q' 'pV̲~q']
#  ['True' 'True' 'False' 'True']
#  ['True' 'False' 'True' 'False']
#  ['False' 'True' 'False' 'False']
#  ['False' 'False' 'True' 'True']]
